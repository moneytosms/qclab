# %%
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import plot_bloch_multivector, plot_histogram
from qiskit_aer import AerSimulator
import numpy as np

# %%
qc1 = QuantumCircuit(1)
state = Statevector.from_instruction(qc1)
print(state)
print('Probabilities:', state.probabilities())
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
# Probabilities: [1. 0.]

# %%
qc2 = QuantumCircuit(1)
qc2.h(0)              # TODO: apply the correct gate to create superposition
state2 = Statevector.from_instruction(qc2)

# %%
print(state2)
print('Probabilities:', state2.probabilities())
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))
# Probabilities: [0.5 0.5]

# %%
qc3 = QuantumCircuit(1)
custom_state = [1/np.sqrt(2), 1j/np.sqrt(2)]     # [alpha, beta]
qc3.initialize(custom_state, 0)     # TODO: fill in the missing argument
state3 = Statevector.from_instruction(qc3)
print(state3)
# Out:
# Statevector([0.70710678+0.j        , 0.        +0.70710678j],
#             dims=(2,))
